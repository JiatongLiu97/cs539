# %% [markdown]
# ## Cluster Demo
#
# Compare kmeans, spectral, and DBSCAN using 4 datasets:
#
# data_uniform.csv, data_noisycircle.csv, data_noisymoon.csv, data_3blobs.csv

# %%
import pandas as pd
import numpy as np
# read the data files.

X = np.array([[-1.5,0], [-0.5,0], [0.5,0], [1.5,0], [-1.5,1.8], [-0.5,1.8], [0.5,1.8], [1.5,1.8]])


print(X)
# Out:
# [[-1.5  0. ]
#  [-0.5  0. ]
#  [ 0.5  0. ]
#  [ 1.5  0. ]
#  [-1.5  1.8]
#  [-0.5  1.8]
#  [ 0.5  1.8]
#  [ 1.5  1.8]]

# %% [markdown]
# Kmeans algorithm

# %%
from sklearn import cluster, datasets
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

colors = np.array([x for x in 'bgrcmykbgrcmykbgrcmykbgrcmyk'])
colors = np.hstack([colors] * 20)

two_means = cluster.MiniBatchKMeans(n_clusters=2)
two_means.fit(X)
y_pred = two_means.labels_.astype(np.int)
plt.plot(-2, 2)
plt.scatter(X[:, 0], X[:, 1], color=colors[y_pred].tolist(), s=6)
plt.show()
# Out:
# C:\Users\75102\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %% [markdown]
# Spectral Clustering

# %%
from sklearn import cluster, datasets
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

colors = np.array([x for x in 'bgrcmykbgrcmykbgrcmykbgrcmyk'])
colors = np.hstack([colors] * 20)

spectral = cluster.SpectralClustering(n_clusters=2)
spectral.fit(X)
y_pred = spectral.labels_.astype(np.int)
plt.plot(2, 2)
plt.scatter(X[:, 0], X[:, 1], color=colors[y_pred].tolist(), s=8)
plt.show()

# %% [markdown]
# DBSCAN: Density Based Spatial Clustering of Applications with Noise

# %%
from sklearn import cluster, datasets
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

colors = np.array([x for x in 'bgrcmykbgrcmykbgrcmykbgrcmyk'])
colors = np.hstack([colors] * 20)

dbscan = cluster.DBSCAN(eps=.1,min_samples=5)
dbscan.fit(X)
y_pred = dbscan.labels_.astype(np.int)
plt.subplot(-2, 2)
plt.scatter(X[i][:, 0], X[i][:, 1], color=colors[y_pred].tolist(), s=10)

plt.show()
